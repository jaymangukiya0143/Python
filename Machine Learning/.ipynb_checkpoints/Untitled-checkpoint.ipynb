# %%
import pandas as pd

# %%
df = pd.read_excel('F:\Showroom\sales.xlsx')
df
# Out:
#          DATE CUSTOMER NAME  MOBILE NUMBER DEPARTMENT ITEM CODE     COLOR  \
# 0  2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP03     BLACK
# 1  2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP03  CHARCOAL
# 2  2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP04     WHITE
# 3  2022-05-29     ASHOKBHAI            NaN     JOCKEY     ZN 05  ASSORTED
# 4         NaT           NaN            NaN        NaN       NaN       NaN
# 5  2022-05-29        OMBHAI            NaN     JOCKEY      FP04     WHITE
# 6  2022-05-29        OMBHAI            NaN     JOCKEY      FP03     BLACK
# 7  2022-05-29        OMBHAI            NaN     JOCKEY      FP03       NaN
# 8         NaT           NaN            NaN        NaN       NaN       NaN
# 9  2022-05-29    MAYANKBHAI            NaN     JOCKEY      7001  ASSORTED
# 10 2022-05-29    MAYANKBHAI            NaN     JOCKEY      7002     NVYML
# 11        NaT           NaN            NaN        NaN       NaN       NaN
# ...

# %%
df = df[df['CUSTOMER NAME']=='ASHOKBHAI']
df
# Out:
#         DATE CUSTOMER NAME  MOBILE NUMBER DEPARTMENT ITEM CODE     COLOR SIZE  \
# 0 2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP03     BLACK    L
# 1 2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP03  CHARCOAL    L
# 2 2022-05-29     ASHOKBHAI            NaN     JOCKEY      FP04     WHITE    L
# 3 2022-05-29     ASHOKBHAI            NaN     JOCKEY     ZN 05  ASSORTED    M
#
#    QTY  ITEM PRICE  TOTAL AMOUNT   STATUS MODE OF PAYMENT
# 0  1.0       299.0           299  PENDING             NaN
# 1  1.0       299.0           299  PENDING             NaN
# 2  2.0       329.0           658  PENDING             NaN
# 3  1.0       359.0           359  PENDING             NaN

# %%
df['TOTAL AMOUNT'].sum()
# Out:
# 1615
